# %% [markdown]
# # Homework 5, Part 2: Answer questions with pandas
#
# **Use the Excel file to answer the following questions.** This is a little more typical of what your data exploration will look like with pandas.
#
# > Again, **don't use ChatGPT for this assignment.** You should be able to memorize the most basic parts of pandas.

# %% [markdown]
# ## 0) Setup
#
# Import pandas **with the correct name** .

# %%
# !pip install pandas 
import pandas as pd
# Out:
# Requirement already satisfied: pandas in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 1) Reading in an Excel file
#
# Use pandas to read in the `richpeople.xlsx` Excel file, saving it as a variable with the name we'll always use for a dataframe.
#
# > **TIP:** You will use `read_excel` instead of `read_csv`. Trying `read_excel` the first time will probably not work, you'll get an error message. Be sure to read the error carefully: *you probably need to install a new library before it will work, and the error tells you what the library is named*. You *might* need to do `Kernel > Restart Kernel...` and run the notebook again from the top in order to get it to work.

# %%
# !pip install openpyxl
import openpyxl
df = pd.read_excel("richpeople.xlsx")
# Out:
# Requirement already satisfied: openpyxl in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from openpyxl) (2.0.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2) Checking your data
#
# Display the number of rows and columns in your data. Also display the names and data types of each column.

# %%
df.shape
# Out:
# (1653, 30)

# %%
df
# Out:
#       year                          name  rank           citizenship  \
# 0     2014          A. Jerrold Perenchio   663         United States
# 1     2014            Abdulla Al Futtaim   687  United Arab Emirates
# 2     2014  Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates
# 3     2014             Abdullah Al Rajhi   731          Saudi Arabia
# 4     2014              Abdulsamad Rabiu  1372               Nigeria
# ...    ...                           ...   ...                   ...
# 1648  2014                     Zhu Yicai  1154                 China
# 1649  2014                 Ziyad Manasir   609                Russia
# 1650  2014            Ziyaudin Magomedov  1372                Russia
# 1651  2014                  Zong Qinghou    94                 China
# 1652  2014            Zygmunt Solorz-Zak   446                Poland
#
#      countrycode  networthusbillion   selfmade              typeofwealth  \
# 0            USA                2.6  self-made                 executive
# 1            ARE                2.5  inherited                 inherited
# 2            ARE                4.8  inherited                 inherited
# 3            SAU                2.4  self-made         self-made finance
# 4            NGA                1.2  self-made       founder non-finance
# ...          ...                ...        ...                       ...
# 1648         CHN                1.5  self-made         self-made finance
# 1649         RUS                2.8  self-made  privatized and resources
# 1650         RUS                1.2  self-made  privatized and resources
# 1651         CHN               11.6  self-made       founder non-finance
# 1652         POL                3.5  self-made       founder non-finance
#
#      gender   age  ...    relationshiptocompany foundingdate gdpcurrentus  \
# 0      male  83.0  ...  former chairman and CEO       1955.0          NaN
# 1      male   NaN  ...                 relation       1930.0          NaN
# 2      male   NaN  ...                 relation       1960.0          NaN
# 3      male   NaN  ...                  founder       1957.0          NaN
# 4      male  54.0  ...                  founder       1988.0          NaN
# ...     ...   ...  ...                      ...          ...          ...
# 1648   male  49.0  ...                  founder       1993.0          NaN
# 1649   male  48.0  ...                  founder       1992.0          NaN
# 1650   male  45.0  ...                  founder       2004.0          NaN
# 1651   male  68.0  ...                  founder       1987.0          NaN
# 1652   male  57.0  ...                  founder       1992.0          NaN
#
#                  sourceofwealth  \
# 0         television, Univision
# 1     auto dealers, investments
# 2                   diversified
# 3                       banking
# 4          sugar, flour, cement
# ...                         ...
# 1648                diversified
# 1649               construction
# 1650                  port, gas
# 1651                  beverages
# 1652            TV broadcasting
#
#                                                notes  notes2  \
# 0     represented Marlon Brando and Elizabeth Taylor     NaN
# 1       company split between him and cousin in 2000     NaN
# 2                              inherited from father     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
# ...                                              ...     ...
# 1648                                             NaN     NaN
# 1649                         close ties with Gazprom     NaN
# 1650                                             NaN     NaN
# 1651                                             NaN     NaN
# 1652                                             NaN     NaN
#
#                                                  source  \
# 0          http://en.wikipedia.org/wiki/Jerry_Perenchio
# 1         http://en.wikipedia.org/wiki/Al-Futtaim_Group
# 2         http://en.wikipedia.org/wiki/Al-Ghurair_Group
# 3            http://en.wikipedia.org/wiki/Al-Rajhi_Bank
# 4       http://www.forbes.com/profile/abdulsamad-rabiu/
# ...                                                 ...
# 1648           http://www.forbes.com/profile/zhu-yicai/
# 1649       http://www.forbes.com/profile/ziyad-manasir/
# 1650         http://www.summagroup.ru/about/history/en/
# 1651          http://en.wikipedia.org/wiki/Zong_Qinghou
# 1652  http://en.wikipedia.org/wiki/Zygmunt_Solorz-%C...
#
#                                                source_2  \
# 0     http://www.forbes.com/profile/a-jerrold-perenc...
# 1     http://www.al-futtaim.ae/content/groupProfile.asp
# 2         http://www.alghurair.com/about-us/our-history
# 3     http://www.alrajhibank.com.sa/ar/investor-rela...
# 4     http://www.bloomberg.com/research/stocks/priva...
# ...                                                 ...
# 1648                                                NaN
# 1649  http://www.themoscowtimes.com/business/article...
# 1650  http://www.forbes.com/profile/ziyaudin-magomedov/
# 1651  http://mic.com/articles/39659/zong-qinghou-chi...
# 1652  No Mob Bosses in This Legal Strategy The New Y...
#
#                                                source_3 source_4
# 0     COLUMN ONE; A Hollywood Player Who Owns the Ga...      NaN
# 1                                                   NaN      NaN
# 2                                                   NaN      NaN
# 3     http://www.alrajhibank.com.sa/ar/about-us/page...      NaN
# 4                                                   NaN      NaN
# ...                                                 ...      ...
# 1648                                                NaN      NaN
# 1649                                                NaN      NaN
# 1650                                                NaN      NaN
# 1651                                                NaN      NaN
# 1652                                                NaN      NaN
#
# [1653 rows x 30 columns]

# %%
df.dtypes
# Out:
# year                         int64
# name                        object
# rank                         int64
# citizenship                 object
# countrycode                 object
# networthusbillion          float64
# selfmade                    object
# typeofwealth                object
# gender                      object
# age                        float64
# industry                    object
# IndustryAggregates          object
# region                      object
# north                        int64
# politicalconnection        float64
# founder                      int64
# generationofinheritance     object
# sector                      object
# company                     object
# companytype                 object
# relationshiptocompany       object
# foundingdate               float64
# gdpcurrentus               float64
# sourceofwealth              object
# notes                       object
# notes2                      object
# source                      object
# source_2                    object
# source_3                    object
# source_4                    object
# dtype: object

# %% [markdown]
# ## 3) Who are the top 10 richest billionaires? Use the `networthusbillion` column.

# %%
df.sort_values(by='networthusbillion', ascending=False).head(10)
# Out:
#       year              name  rank    citizenship countrycode  \
# 184   2014        Bill Gates     1  United States         USA
# 226   2014  Carlos Slim Helu     2         Mexico         MEX
# 79    2014    Amancio Ortega     3          Spain         ESP
# 1562  2014    Warren Buffett     4  United States         USA
# 862   2014     Larry Ellison     5  United States         USA
# 247   2014      Charles Koch     6  United States         USA
# 339   2014        David Koch     6  United States         USA
# 1364  2014   Sheldon Adelson     8  United States         USA
# 280   2014    Christy Walton     9  United States         USA
# 724   2014        Jim Walton    10  United States         USA
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 184                76.0  self-made       founder non-finance    male  58.0
# 226                72.0  self-made  privatized and resources    male  74.0
# 79                 64.0  self-made       founder non-finance    male  77.0
# 1562               58.2  self-made       founder non-finance    male  83.0
# 862                48.0  self-made       founder non-finance    male  69.0
# 247                40.0  inherited                 inherited    male  78.0
# 339                40.0  inherited                 inherited    male  73.0
# 1364               38.0  self-made         self-made finance    male  80.0
# 280                36.7  inherited                 inherited  female  59.0
# 724                34.7  inherited                 inherited    male  66.0
#
#       ... relationshiptocompany foundingdate gdpcurrentus      sourceofwealth  \
# 184   ...               founder       1975.0          NaN           Microsoft
# 226   ...               founder       1990.0          NaN             telecom
# 79    ...               founder       1975.0          NaN              retail
# 1562  ...               founder       1839.0          NaN  Berkshire Hathaway
# 862   ...               founder       1977.0          NaN              Oracle
# 247   ...              relation       1940.0          NaN         diversified
# 339   ...              relation       1940.0          NaN         diversified
# 1364  ...               founder       1952.0          NaN             casinos
# 280   ...              relation       1962.0          NaN            Wal-Mart
# 724   ...              relation       1962.0          NaN            Wal-Mart
#
#                       notes  notes2  \
# 184                     NaN     NaN
# 226                     NaN     NaN
# 79                      NaN     NaN
# 1562                    NaN     NaN
# 862                     NaN     NaN
# 247   inherited from father     NaN
# 339   inherited from father     NaN
# 1364                    NaN     NaN
# 280                   widow     NaN
# 724   inherited from father     NaN
#
#                                                  source  \
# 184           http://www.forbes.com/profile/bill-gates/
# 226   http://www.ozy.com/provocateurs/carlos-slims-w...
# 79        http://www.forbes.com/profile/amancio-ortega/
# 1562  http://www.forbes.com/lists/2009/10/billionair...
# 862        http://www.forbes.com/profile/larry-ellison/
# 247   http://www.kochind.com/About_Koch/History_Time...
# 339   http://www.kochind.com/About_Koch/History_Time...
# 1364     http://www.forbes.com/profile/sheldon-adelson/
# 280       http://www.forbes.com/profile/christy-walton/
# 724           http://www.forbes.com/profile/jim-walton/
#
#                                                source_2 source_3 source_4
# 184                                                 NaN      NaN      NaN
# 226                                                 NaN      NaN      NaN
# 79                                                  NaN      NaN      NaN
# 1562  http://www.forbes.com/companies/berkshire-hath...      NaN      NaN
# 862   http://www.businessinsider.com/how-larry-ellis...      NaN      NaN
# 247                                                 NaN      NaN      NaN
# 339                                                 NaN      NaN      NaN
# 1364  http://lasvegassun.com/news/1996/nov/26/rat-pa...      NaN      NaN
# 280                                                 NaN      NaN      NaN
# 724                                                 NaN      NaN      NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# ## 4a) How many male billionaires are there compared to the number of female billionares?
#
# > **TIP:** This is not a `.groupby`

# %%
df['gender'].value_counts()
# Out:
# gender
# male      1473
# female     180
# Name: count, dtype: int64

# %% [markdown]
# ## 4b) What percent is that?
#
# > **TIP:** Doing percentages with the answer to `4a` is so common that there's an extra parameter to automatically calculate it. Look at the documentation!

# %%
df['gender'].value_counts(normalize=True) * 100
# Out:
# gender
# male      89.110708
# female    10.889292
# Name: proportion, dtype: float64

# %% [markdown]
# ## 4c) Is the average wealth different for a female billionaire as compared to a male billionaire?
#
# > **TIP:** This one *does* use `.groupby`. You can pick what 'average' means in this context.

# %%
df[df['gender'] == 'male']['networthusbillion'].mean()
# Out:
# np.float64(3.9027155465037335)

# %%
df[df['gender'] == 'female']['networthusbillion'].mean()
# Out:
# np.float64(3.9205555555555547)

# %% [markdown]
# ## 5a) What is the most common source/type of wealth?

# %%
df['typeofwealth'].value_counts()
# Out:
# typeofwealth
# inherited                   506
# founder non-finance         467
# self-made finance           344
# privatized and resources    192
# executive                   142
# Name: count, dtype: int64

# %% [markdown]
# ## 5b) Is the most common source/type of wealth different between men and women?
#
# > **TIP:** You know how to `groupby` and you know how to count how many times a value is in a column. Can you put them together??? You could also do this as two separate cells where you calculate it separately for men and women.
# >
# > **TIP:** Use percentages for this, it makes it a lot more readable.

# %%
df.groupby('gender')['typeofwealth'].value_counts(normalize=True) * 100
# Out:
# gender  typeofwealth
# female  inherited                   78.888889
#         founder non-finance         11.666667
#         executive                    3.333333
#         self-made finance            3.333333
#         privatized and resources     2.777778
# male    founder non-finance         30.319511
#         inherited                   24.745071
#         self-made finance           22.977566
#         privatized and resources    12.712441
#         executive                    9.245411
# Name: proportion, dtype: float64

# %% [markdown]
# ## 6a) What companies have the most billionaires? Let's see the top five.
#
# > **TIP:** You can use `.head()` on *anything*, not just your basic `df`
# >
# > **TIP:** You might feel like you should use `groupby`, but don't! There's an easier way to count.

# %%
df['company'].value_counts().head(5)
# Out:
# company
# Hyatt                  11
# Oetker-Gruppe           8
# S. C. Johnson & Son     7
# Cargill                 6
# Alfa Group              6
# Name: count, dtype: int64

# %% [markdown]
# ### 6b) Graph those top 5 as a horizontal bar graph. Make the largest bar be at the top of the graph.
#
# > **TIP:** Just try to throw `.plot()` on the end??
# >
# > **TIP:** Make the largest bar be at the top of the graph
# >
# > **TIP:** If your chart seems... weird, think about where in the process you're sorting vs using `head`

# %%
# !pip install matplotlib
df['company'].value_counts().head().sort_values(ascending=True).plot(kind='barh')
# Out:
# Requirement already satisfied: matplotlib in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from matplotlib) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from matplotlib) (2.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\olivi\.pyenv\pyenv-win\versions\3.12.10\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# <Axes: ylabel='company'>

# %% [markdown]
# ## 7) How much money do these top 5 billionaires have in total?
#
# > **TIP:** for multiple conditions, you can't use `or` and `and`. In pandas, `|` means *or* and `&` means *and*.
# >
# > **TIP:** Checking multiple conditions can be done two ways.
# > - `(df.colname == 'A') | (df.colname == 'B')`
# > - `df.colname.isin(['A', 'B'])`

# %%
### Note: was slightly confused by this question, read this as the top 5 richest billionaires, separate from the previous question about the top 5 companies

### Also got stuck on this for a while so moved on!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 2
#       1 ### Note: was slightly confused by this question, read this as the top 5 richest billionaires, separate from the previous question about the top 5 companies
# ----> 2 df('networthusbillion', ascending=False).head()
#       3 ### Also got stuck on this for a while so moved on!
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# ## 8) What are the top 10 countries with the most money held by billionaires?
#
# I am **not** asking which country has the most billionaires - this is **total amount of money per country.**
#
# > **TIP:** Think about it in steps - "I want them organized by country," "I want their net worth," "I want to add it all up," and "I want 10 of them." Just chain it all together.

# %%
df.groupby('country')['networthusbillion'].sort_values(ascending=False).sum().head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df.groupby('country')['networthusbillion'].sort_values(ascending=False).sum().head(10)
#
# File ~\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# File ~\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~\.pyenv\pyenv-win\versions\3.12.10\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'country'

# %% [markdown]
# ## 9a) How old is an average billionaire?

# %% [markdown]
# ## 9b) How old are self-made billionaires compared to non self-made billionaires?

# %% [markdown]
# ## 10a) Who are the three youngest billionaires? Who are the three oldest?

# %% [markdown]
# ## 10b) Make a graph of the distribution of ages.
#
# > **TIP:** You use `.plot()` to graph values in a column independently, but `.hist()` to draw a [histogram](https://www.mathsisfun.com/data/histograms.html) of the distribution of their values

# %% [markdown]
# ## 11) Make a scatterplot of net worth compared to age
#
# It's more fun to do this in Altair as compared to matplotlib, but either is fine.

# %% [markdown]
# ## 13) Make a bar graph of the wealth of the top 10 richest billionaires
#
# > **TIP:** When you make your plot, you'll need to set the `x` and `y` or else your chart will look _crazy_
# >
# > **TIP:** x and y might be the opposite of what you expect them to be

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df.sort_values(by='networthusbillion', ascending=False)('name').head(10).plot(kind='barh')
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# ## 14) Read in the most recent data
#
# I copied and pasted the most recent data from [the original Bloomberg story](https://www.bloomberg.com/billionaires/) (it's in the page's source code), but it all was saved as JSON. Can you use pandas to read in `billionaires.json`?
#
# > **TIP:** If `pd.read_csv` reads a CSV and `pd.read_excel` reads an excel file... what reads in JSON?
# >
# > **TIP:** It's a lot less complicated than what we did in class.

# %%
pd.read_json("billionaires.json").head(20)
# Out:
#                       commonName      commonLastName    citizenship  \
# 0                      Elon Musk                Musk  United States
# 1                Bernard Arnault             Arnault         France
# 2                     Jeff Bezos               Bezos  United States
# 3                     Bill Gates               Gates  United States
# 4                  Larry Ellison             Ellison  United States
# 5                  Steve Ballmer             Ballmer  United States
# 6                Mark Zuckerberg          Zuckerberg  United States
# 7                     Larry Page                Page  United States
# 8                 Warren Buffett             Buffett  United States
# 9                    Sergey Brin                Brin  United States
# 10  Francoise Bettencourt Meyers  Bettencourt Meyers         France
# 11                   Carlos Slim                Slim         Mexico
# 12                 Mukesh Ambani              Ambani          India
# 13                Amancio Ortega              Ortega          Spain
# 14                    Jim Walton              Walton  United States
# 15                    Rob Walton              Walton  United States
# 16                  Alice Walton              Walton  United States
# 17                  Michael Dell                Dell  United States
# 18   Julia Flesher Koch & family        Flesher Koch  United States
# 19                Zhong Shanshan               Zhong          China
#
#                             slug     industry  personId  rank         worth  \
# 0                    elon-r-musk   Technology   1954518     1  221116780866
# 1              bernard-j-arnault     Consumer   1392853     2  170267873036
# 2                jeffrey-p-bezos   Technology   1642252     3  169556171871
# 3                william-h-gates   Technology   1390479     4  131137012631
# 4             lawrence-j-ellison   Technology   1491757     5  129608081535
# 5               steven-a-ballmer   Technology   1390481     6  127674393229
# 6              mark-e-zuckerberg   Technology  15103277     7  121727717679
# 7                lawrence-e-page   Technology   1923756     8  120489590879
# 8               warren-e-buffett  Diversified   1387055     9  118523728929
# 9                  sergey-m-brin   Technology   2506013    10  114296942954
# 10  francoise-bettencourt-meyers     Consumer   1899183    11   92345172940
# 11              carlos-slim-helu  Diversified   1393747    12   91172643823
# 12               mukesh-d-ambani       Energy   1784869    13   86493412249
# 13          amancio-ortega-gaona       Retail   3333475    14   76785074014
# 14                  jim-c-walton       Retail   1654596    15   73934583769
# 15               samuel-r-walton       Retail   1481595    16   72710329421
# 16                alice-l-walton       Retail   1552607    17   71649168242
# 17                michael-s-dell   Technology   1443674    18   67541494811
# 18                  julia-f-koch   Industrial  17557425    19   64445385270
# 19                shanshan-zhong  Diversified  20868308    20   62779518714
#
#     lastChange  lastPercentChange    ytdChange  ytdPercentChange       sector  \
# 0   9795811154               4.64  84106712938             61.39   Technology
# 1   7356040557               4.52   8178459368              5.05     Consumer
# 2   3202661603               1.93  62599942079             58.53   Technology
# 3   1103482475               0.85  21900118029             20.05   Technology
# 4   2286642464               1.80  37780140594             41.14   Technology
# 5   1147564868               0.91  41866122956             48.79   Technology
# 6   2496111771               2.09  76114221811            166.87   Technology
# 7   1318835656               1.11  37559747629             45.29   Technology
# 8   1334959503               1.14  11065137784             10.30  Diversified
# 9   1241492329               1.10  34929098952             44.01   Technology
# 10  3505643083               3.95  20835217696             29.14     Consumer
# 11  2832442268               3.21  16850804396             22.67  Diversified
# 12           0               0.00   -616324720             -0.71       Energy
# 13  2580078300               3.48  22158367944             40.56       Retail
# 14    75503136               0.10  10063886306             15.76       Retail
# 15    50611783               0.07   9489847542             15.01       Retail
# 16    15525051               0.02  10013702244             16.25       Retail
# 17   -35544001              -0.05  19134357639             39.53   Technology
# 18   979465200               1.54  -2579497040             -3.85   Industrial
# 19  -308389961              -0.49  -4776579530             -7.07  Diversified
#
#     fWorth fLastChange fYtdChange fLastPercentChange fYtdPercentChange
# 0    $221B     +$9.80B    +$84.1B              +4.6%            +61.4%
# 1    $170B     +$7.36B    +$8.18B              +4.5%             +5.0%
# 2    $170B     +$3.20B    +$62.6B              +1.9%            +58.5%
# 3    $131B     +$1.10B    +$21.9B              +0.8%            +20.1%
# 4    $130B     +$2.29B    +$37.8B              +1.8%            +41.1%
# 5    $128B     +$1.15B    +$41.9B              +0.9%            +48.8%
# 6    $122B     +$2.50B    +$76.1B              +2.1%           +166.9%
# 7    $120B     +$1.32B    +$37.6B              +1.1%            +45.3%
# 8    $119B     +$1.33B    +$11.1B              +1.1%            +10.3%
# 9    $114B     +$1.24B    +$34.9B              +1.1%            +44.0%
# 10  $92.3B     +$3.51B    +$20.8B              +4.0%            +29.1%
# 11  $91.2B     +$2.83B    +$16.9B              +3.2%            +22.7%
# 12  $86.5B          $0     -$616M                 0%             -0.7%
# 13  $76.8B     +$2.58B    +$22.2B              +3.5%            +40.6%
# 14  $73.9B     +$75.5M    +$10.1B              +0.1%            +15.8%
# 15  $72.7B     +$50.6M    +$9.49B              +0.1%            +15.0%
# 16  $71.6B     +$15.5M    +$10.0B              +0.0%            +16.3%
# 17  $67.5B     -$35.5M    +$19.1B              -0.1%            +39.5%
# 18  $64.4B      +$979M    -$2.58B              +1.5%             -3.9%
# 19  $62.8B      -$308M    -$4.78B              -0.5%             -7.1%
